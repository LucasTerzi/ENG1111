# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasTerzi/ENG1111/blob/main/LucasTerzi_2110256_Lista3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Professor, tive dúvidas no items 7 e uma parte no 10. Não sei se estão da forma que o senhor gostaria.

# %%
#1 e 2)

import pandas as pd
from google.colab import drive

drive.mount('/drive')

dados= pd.read_csv('/drive/MyDrive/class_titanic.csv')
dados= pd.DataFrame(dados)

display(dados)
# Out:
# Mounted at /drive
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
#3)

dados = dados.dropna(subset=['Age'])
dados
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 885          886       3               Rice, Mrs. William (Margaret Norton)
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
#4)

media = dados["Age"].mean()
print(media)
# Out:
# 28.947916666666668

# %%
#5)
dados.drop(dados[dados["Age"] >= 50].index, inplace = True)
dados.drop(dados[dados['Age'] <=10 ]. index, inplace = True)

pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 9)

display(dados)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
#         Sex   Age  ...            Ticket     Fare Cabin  Embarked Survived
# 0      male  22.0  ...         A/5 21171   7.2500   NaN         S        0
# ...

# %%
#6)

dados2 = pd.read_csv("/drive/MyDrive/class_titanic.csv")


dados2.drop(columns=['Pclass','SibSp','Fare','Parch','Cabin', 'Embarked', 'Survived'], inplace = True)

display(dados2)
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# ..           ...                                                ...     ...
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age            Ticket
# 0    22.0         A/5 21171
# 1    38.0          PC 17599
# 2    26.0  STON/O2. 3101282
# 3    35.0            113803
# ..    ...               ...
# 887  19.0            112053
# ...

# %%
#7)

coluna1= dados['Name']
coluna2=dados['Age']
coluna3= dados['Sex']
coluna4= dados['PassengerId']
coluna5=dados['Ticket']

dados['colunaX']= (coluna4 - coluna2)* 0.7
display(dados)
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
#         Sex   Age  ...     Fare  Cabin Embarked  Survived colunaX
# 0      male  22.0  ...   7.2500    NaN        S         0   -14.7
# 1    female  38.0  ...  71.2833    C85        C         1   -25.2
# ...

# %%
#8)
import numpy as np

dados3 = dados.reindex(np.random.permutation(dados.index))

pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 7)
display(dados3)
# Out:
#      PassengerId  Pclass                                            Name  \
# 579          580       3                             Jussila, Mr. Eiriik
# 436          437       3            Ford, Miss. Doolina Margaret "Daisy"
# 855          856       3                      Aks, Mrs. Sam (Leah Rosen)
# ..           ...     ...                                             ...
# 830          831       3         Yasbeck, Mrs. Antoni (Selini Alexander)
# 809          810       1  Chambers, Mrs. Norman Campbell (Bertha Griggs)
# 671          672       1                          Davidson, Mr. Thornton
#
#         Sex   Age  ...             Ticket     Fare Cabin  Embarked Survived
# 579    male  32.0  ...  STON/O 2. 3101286   7.9250   NaN         S        1
# 436  female  21.0  ...         W./C. 6608  34.3750   NaN         S        0
# 855  female  18.0  ...             392091   9.3500   NaN         S        1
# ..      ...   ...  ...                ...      ...   ...       ...      ...
# ...

# %%
#9)
dados = pd.read_csv("class_titanic.csv")

dados = dados.sort_values(by='Name', ascending=True)
print(f"A primeira pessoa em ordem alfabética é: {dados['Name'].iloc[0]}")      
pd.set_option('display.max_columns', 6)
pd.set_option('display.max_rows', 8)
display(dados)

#Ordenei por ordem alfabética
# Out:
# A primeira pessoa em ordem alfabética é: Abbing, Mr. Anthony
#      PassengerId  Pclass                              Name  ... Cabin  \
# 845          846       3               Abbing, Mr. Anthony  ...   NaN
# 746          747       3       Abbott, Mr. Rossmore Edward  ...   NaN
# 279          280       3  Abbott, Mrs. Stanton (Rosa Hunt)  ...   NaN
# 308          309       2               Abelson, Mr. Samuel  ...   NaN
# ..           ...     ...                               ...  ...   ...
# 282          283       3         de Pelsmaeker, Mr. Alfons  ...   NaN
# 361          362       2         del Carlo, Mr. Sebastiano  ...   NaN
# 153          154       3   van Billiard, Mr. Austin Blyler  ...   NaN
# 868          869       3       van Melkebeke, Mr. Philemon  ...   NaN
#
#      Embarked  Survived
# 845         S         0
# 746         S         0
# 279         S         1
# 308         C         0
# ..        ...       ...
# 282         S         0
# 361         C         0
# ...

# %%
#10)

pd.set_option('display.max_columns', 4)
pd.set_option('display.max_rows', 7)

grupo = dados.groupby('PassengerId')[['Age']].mean()

display(grupo)

#Essa segunda parte não está rodando, não sei identificar o erro
#grupo2 = dados.groupby('Name ')[['Name ']].count()

#display(grupo2)
# Out:
#               Age
# PassengerId
# 1            22.0
# 2            38.0
# 3            26.0
# ...           ...
# 889           NaN
# 890          26.0
# 891          32.0
#
# [891 rows x 1 columns]

# %%
#11)

dados['Status Fin'] = dados['Pclass'].map(
    {1: 'Muito Rico', 2: 'Rico', 3: ' Pobre'})
pd.set_option('display.max_columns', 7)
pd.set_option('display.max_rows', 9)
display(dados)

# Nesse item fiz com que todos os passageiros com Pclass = 1 fossem considerados 'Muito Ricos', 
# todos os passageiros com Pclass =2 fossem considerados 'Ricos' e todos que tem Pclass=3 'Pobres'.
# Out:
#      PassengerId  Pclass                              Name  ... Embarked  \
# 845          846       3               Abbing, Mr. Anthony  ...        S
# 746          747       3       Abbott, Mr. Rossmore Edward  ...        S
# 279          280       3  Abbott, Mrs. Stanton (Rosa Hunt)  ...        S
# 308          309       2               Abelson, Mr. Samuel  ...        C
# ..           ...     ...                               ...  ...      ...
# 282          283       3         de Pelsmaeker, Mr. Alfons  ...        S
# 361          362       2         del Carlo, Mr. Sebastiano  ...        C
# 153          154       3   van Billiard, Mr. Austin Blyler  ...        S
# 868          869       3       van Melkebeke, Mr. Philemon  ...        S
#
#      Survived  Status Fin
# 845         0       Pobre
# 746         0       Pobre
# 279         1       Pobre
# 308         0        Rico
# ..        ...         ...
# 282         0       Pobre
# 361         0        Rico
# ...

# %%
#12

from google.colab import drive
drive.mount ('/drive')
dados.to_csv('/drive/MyDrive/df.csv')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
#13

import json
from google.colab import drive
drive.mount ('/drive')
arquivo= dados.to_json()
dados.to_json('/drive/MyDrive/arq.json')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
